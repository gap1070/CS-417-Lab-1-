# %% [markdown]
# <a href="https://colab.research.google.com/github/gap1070/CS-417--Lab-1-/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
#
# **Date:** Jan. 28, 2026
#
# This notebook demonstrates basic Python concepts including:
#
# - Print statements
#
# - Variables
#
# - Basic arithmetic operations
#
# - String formatting

# %%
# Basic print statements

print("Welcome to Google Colab!")

print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables

favorite_food = "sushi"

favorite_number = 20

favorite_color = "light blue"


print("My favorite food is:", favorite_food)

print("My favorite number is:", favorite_number)

print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: sushi
# My favorite number is: 20
# My favorite color is: light blue

# %%
# My own code

# 2 variables and assigned values
monthly_income = 1000
mounty_expenses = 400

# 1 operation
monthly_savings = monthly_income - mounty_expenses

# print monthly savings
print("My monthly savings are:", monthly_savings)
# Out:
# My monthly savings are: 600
